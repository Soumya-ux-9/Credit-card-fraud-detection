# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

from sklearn.cluster import KMeans

# %%
df=pd.read_csv("creditcard.csv")

# %%
df.shape
# Out:
# (140703, 31)

# %%
df.info
# Out:
# <bound method DataFrame.info of          Time        V1        V2        V3        V4        V5        V6  \
# 0           0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1           0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2           1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3           1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4           2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...       ...       ...       ...       ...       ...       ...       ...
# 140698  83876  1.297031  0.260234 -0.165836  0.304460  0.238056 -0.084983
# 140699  83876  1.200272  0.259410  0.397862  0.631576 -0.476806 -0.882324
# 140700  83877 -0.939078  1.234767  1.433774 -0.097576 -0.255769 -0.689204
# 140701  83879  1.170286  0.563313 -0.271928  1.394477 -0.038260 -1.000654
# 140702  83879 -1.376888  0.304186  2.232899 -0.740000       NaN       NaN
#
# ...

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  140703.000000  140703.000000  140703.000000  140703.000000
# mean    52017.063240      -0.249590       0.018631       0.672709
# std     20935.874366       1.815360       1.612924       1.267514
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     38001.000000      -1.020857      -0.563417       0.169911
# 50%     53833.000000      -0.270868       0.105003       0.750128
# 75%     69573.000000       1.157957       0.777163       1.362846
# max     83879.000000       1.960497      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  140703.000000  140702.000000  140702.000000  140702.000000
# mean        0.139629      -0.282394       0.079221      -0.117074
# std         1.321903       1.306687       1.283716       1.166104
# min        -5.519697     -42.147898     -26.160506     -31.764946
# ...

# %%
df['Time'].value_counts()
# Out:
# Time
# 64947    26
# 68780    25
# 3767     21
# 3770     20
# 19912    19
#          ..
# 64788     1
# 64787     1
# 33119     1
# 33120     1
# 29924     1
# Name: count, Length: 60519, dtype: int64

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize=(12,8))
ax=fig.add_subplot(111, projection='3d')
ax.scatter(df['Time'], df['Amount'], df['Class'],c=df['Class'])

# %%
x=df.drop('Class',axis=1)
y=df['Class']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
scaler=StandardScaler()

# %%
scaled_x_train=scaler.fit_transform(x_train)
scaled_x_test=scaler.transform(x_test)

# %%
mask=~np.isnan(y_train)
scaled_x_train_clean=scaled_x_train[mask]
y_train_clean=y_train[mask]
log_model.fit(scaled_x_train_clean,y_train_clean)
# Out:
# LogisticRegression()

# %%
print(np.isnan(scaled_x_train).sum()) #checking number of NaNs in scaled_x_train
# Out:
# 25

# %%
mask=~np.isnan(scaled_x_train).any(axis=1)
scaled_x_train_clean=scaled_x_train[mask]
y_train_clean=y_train[mask]
log_model.fit(scaled_x_train_clean,y_train_clean)
# Out:
# LogisticRegression()

# %%
from sklearn.linear_model import LogisticRegression

# %%
x.drop(23857)
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0           0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1           0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2           1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3           1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4           2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...       ...       ...       ...       ...       ...       ...       ...
# 140698  83876  1.297031  0.260234 -0.165836  0.304460  0.238056 -0.084983
# 140699  83876  1.200272  0.259410  0.397862  0.631576 -0.476806 -0.882324
# 140700  83877 -0.939078  1.234767  1.433774 -0.097576 -0.255769 -0.689204
# 140701  83879  1.170286  0.563313 -0.271928  1.394477 -0.038260 -1.000654
# 140702  83879 -1.376888  0.304186  2.232899 -0.740000       NaN       NaN
#
#               V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
log_model=LogisticRegression()
# Use the cleaned datasets to fit the model
log_model.fit(scaled_x_train_clean,y_train_clean)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,recall_score,precision_score,f1_score

# %%
y_pred=log_model.predict(scaled_x_test)

# %%
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
y_pred_prob=log_model.predict_proba(scaled_x_test)
y_pred_prob
# Out:
# array([[9.99635279e-01, 3.64720571e-04],
#        [9.79680982e-01, 2.03190178e-02],
#        [9.99826162e-01, 1.73837942e-04],
#        ...,
#        [9.99789224e-01, 2.10776323e-04],
#        [9.99992563e-01, 7.43662377e-06],
#        [9.99810499e-01, 1.89501476e-04]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9989339398031342

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[28078,    12],
#        [   18,    33]])

# %%
recall_score(y_test,y_pred)
# Out:
# 0.6470588235294118

# %%
f1_score(y_test,y_pred)
# Out:
# 0.6875
